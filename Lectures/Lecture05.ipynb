# %% [markdown]
# Lecture 5: Making the Earth

# %%
nb_list = !jupyter notebook list
server = [l for l in nb_list if 'eos240' in l][0].split(' :: ')[0]
prefix = server.split('?')[0]
token = server.split('?')[1]
notebook = 'Lecture05.ipynb'
url = prefix+'notebooks/'+notebook+'?'+token
# !decktape -s '1920x1080' rise $url pdf_slides/Lecture05.pdf
# Out:
# Loading page http://localhost:8888/notebooks/Lecture05.ipynb?token=e55cdff96894243a0dd0821d20731e412966a6ed8df7b75e ...
# actions jupyter-notebook:find-and-replace does not exist, still binding it in case it will be defined later...
# load_extensions {
#   '0': 'nbextensions_configurator/config_menu/main',
#   '1': 'contrib_nbextensions_help_item/main',
#   '2': 'rise/main',
#   '3': 'jupyter-js-widgets/extension',
#   '4': 'jupyter-black-master/jupyter-black',
#   '5': 'toc2/main',
#   '6': 'hide_code/hide_code',
#   '7': 'hide_input/main',
#   '8': 'codefolding/main',
#   '9': 'splitcell/splitcell'
# }
# Loaded moment locale en-gb
# Failed to load resource: the server responded with a status of 404 (Not Found)
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'background: url(images/andromeda.jpg) 50% 60% no-repeat;\n' +
#     '  width: 1290px;\n' +
#     '  height: 181px; background-size: 100%;',
#   newValue: 'background: url("images/andromeda.jpg") 50% 60% no-repeat ; width: 1290px ; height: 181px ; background-size: 100%'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'font-size:25px',
#   newValue: 'font-size: 25px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'font-size:25px',
#   newValue: 'font-size: 25px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:800px;',
#   newValue: 'height: 800px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:800px',
#   newValue: 'height: 800px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:800px;',
#   newValue: 'height: 800px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:800px',
#   newValue: 'height: 800px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:550px;',
#   newValue: 'height: 550px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:550px',
#   newValue: 'height: 550px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;',
#   newValue: 'font-weight: 600'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:750px;',
#   newValue: 'height: 750px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:750px',
#   newValue: 'height: 750px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;',
#   newValue: 'font-weight: 600'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:650px;',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:650px',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px;visibility:hidden',
#   newValue: 'height: 700px ; visibility: hidden'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:550px;',
#   newValue: 'height: 550px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:550px',
#   newValue: 'height: 550px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:650px;',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:650px',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:650px;',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:650px',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:650px;',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:650px',
#   newValue: 'height: 650px'
# }
# Session: kernel_created (5395fad6-25ae-441a-97c5-63c34e9f00ce)
# Starting WebSockets: ws://localhost:8888/api/kernels/e1f2630d-edcf-4975-b682-1a84c06530b7
# Failed to load extension: [ 'nbextensions/hide_code/hide_code' ] {
#   requireType: 'scripterror',
#   requireModules: [ 'nbextensions/hide_code/hide_code' ],
#   originalError: { isTrusted: true }
# }
# Loading extension: rise/main
# Loading extension: nbextensions_configurator/config_menu/main
# Loading extension: contrib_nbextensions_help_item/main
# Loading extension: hide_input/main
# Loading extension: splitcell/splitcell
# Kernel: kernel_connected (e1f2630d-edcf-4975-b682-1a84c06530b7)
# Loading extension: jupyter-js-widgets/extension
# Failed to load resource: the server responded with a status of 404 (Not Found)
# Widgets are not available.  Please install widgetsnbextension or ipywidgets 4.0
# Loading extension: toc2/main
# [toc2] Notebook fully loaded -- toc2 initialized
# Loading extension: codefolding/main
# Loading extension: jupyter-black-master/jupyter-black
# Access to font at 'about:blank' from origin 'http://localhost:8888' has been blocked by CORS policy: Cross origin requests are only supported for protocol schemes: http, data, chrome, chrome-untrusted, https.
#
# Unable to load resource from URL: about:blank
# Failed to load resource: net::ERR_FAILED
# Loading page finished with status: 200
# RISE plugin activated
# Refused to apply style from 'http://localhost:8888/notebooks/Lecture05.css' because its MIME type ('text/html') is not a supported stylesheet MIME type, and strict MIME checking is enabled.
# Codefolding: Wait for 1000 ms
# Failed to load resource: the server responded with a status of 404 (Not Found)
# Failed to get file none.json. ReadyState: 4, Status: 404
# Printing slide #/slide-15-0 (18/16) ...
# Printed 18 slides

# %% [markdown]
# <center><div style="background: url(images/andromeda.jpg) 50% 60% no-repeat;
#   width: 1290px;
#   height: 181px; background-size: 100%;">
# </div></center>

# %% [markdown]
# # Lecture 5: Making the Earth
# <div style='font-size:25px'>
#
#
# 1. Condensation temperatures
# 1. Goldschmidt classification
# 1. The primitive mantle
#
# </div>

# %% [markdown]
# <div style='font-size:25px'> <i>We acknowledge and respect the lək̓ʷəŋən peoples on whose traditional territory the university stands and the Songhees, Esquimalt and W̱SÁNEĆ peoples whose historical relationships with the land continue to this day. </i></div>

# %% [markdown]
# <center>
#     <div style='height:800px;'>
# 	    <img src="images/condensation.png" style='height:800px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <span style='font-weight:600;color:DodgerBlue'>Which 6 elements make up most of Earth's mass?</span>
# </center>

# %% [markdown]
# <center>
#     <div style='height:800px;'>
# 	    <img src="images/condensation.png" style='height:800px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <span style='font-weight:600;color:DodgerBlue'>Earth $\approx$ MgO + CaO + SiO$_2$ + Al$_2$O$_3$ + FeO</span>
# </center>

# %% [markdown]
# <span style='font-weight:600;color:DodgerBlue'>Define Goldschmidt classification.</span><p></p>

# %% [markdown]
# <center>
#     <div style='height:550px;'>
# 	    <img src="images/gs_class.png" style='height:550px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <span style='font-weight:600;color:DodgerBlue'>Describe the arrangement of Lithophile vs Siderophile elements in the periodic table. What might explain this arrangement?</span><p></p>

# %% [markdown]
# <span style='font-weight:600;'>Electronegativity</span><p></p>
#
# *an atom's ability to attract shared electrons in a chemical bond*

# %% [markdown]
# <center>
#     <div style='height:750px;'>
# 	    <img src="images/electronegativity.png" style='height:750px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <span style='font-weight:600;'>Silicate melt structure,</span> is *oxyphile* a better word? <br>

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/silicate_melt.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# In Geochemistry, we often use the word **fractionate** to indicate that the original mass (*the nebula*) led to one or more smaller fractions of mass (*different planets*) that have compositional variations. Through our understanding of condensation temperatures and Goldschmidt's classification scheme, planet *formation* and planetary *differentiation* lead to predictable fractionations, and so the chemistry of a rock can tell us a lot about how it came to be.

# %% [markdown]
# Some review questions to consider:
#
# - <span style='font-weight:600;color:DodgerBlue'>How does the Ca/Al ratio change from the inner solar system to the outer?</span> *(draw a figure showing this ratio vs distance from the Sun)*<br>
# - <span style='font-weight:600;color:DodgerBlue'>How does the Na/Al ratio change from the inner solar system to the outer?</span> *(draw a figure showing this ratio vs distance from the Sun)*<br>
# - <span style='font-weight:600;color:DodgerBlue'>Is the weight % of CaO of **Bulk** Earth higher or lower than the weight % of CaO of **Bulk** Jupiter?</span><br>
# - <span style='font-weight:600;color:DodgerBlue'>Is the Si/Fe ratio higher in an undifferentiated meteorite or the Earth's mantle?</span><br>
# <p></p>

# %% [markdown]
# <span style='font-weight:600;color:DodgerBlue'>Define Primitive Mantle. What do we know about the modern mantle?</span><br>
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L4_S28_F0.svg" style='height:700px'/></center>

# %% [markdown]
# Olivine Solid Solution Phase Diagram.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L4_S29_F0.svg" style='height:700px'/></center>

# %% [markdown]
# Melting trends.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L4_S30_F0.svg" style='height:700px'/></center>

# %% [markdown]
# <center><img src="chalkboard_images/L5_S31_F0.svg" style='height:700px;visibility:hidden'/></center>
#
#
#
# **Pyrolite Model**: Ringwood, A.E., 1962. **A model for the upper mantle**. *Journal of Geophysical Research*.

# %% [markdown]
# <center><img src="chalkboard_images/L5_S31_F0.svg" style='height:700px'/></center>
#
#
#
# **Pyrolite Model**: Ringwood, A.E., 1962. **A model for the upper mantle**. *Journal of Geophysical Research*.

# %% [markdown]
# Chondrites
# <center>
#     <div style='height:550px;'>
# 	    <img src="images/cai.jpg" style='height:550px'>
#     </div>
# </center>
#
# Chondrules: molten 'droplets' of nebular dust
# AOAs: Ameboidal Olivine Aggregates ~100% olivine
# CAIs: Calcium Aluminum Inclusions are the first condensates

# %% [markdown]
# Mineralogy of Chondrite phases
#
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/chondrite_phases.jpg" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# Chondrites have variable composition
#
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/mg_si_chond.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# ### Practice problem
# The observed chondritic mass abundances for Calcium and Aluminum are:
#
# | Element        | wt % in Chondrite           | Atomic Mass  |
# | ------------- |:-------------:| -----:|
# | Ca | 0.92     |    40.1 |
# | Al | 0.85      |    27 |
#
# The average wt % of CaO and Al$_2$O$_3$ in Basalt and Harzburgite:
#
# | **Oxide**        | wt % in Basalt           | wt % in Harzburgite   |
# | ------------- |:-------------:| -----:|
# | CaO | 11.3     |   6.1 |
# | Al$_2$O$_3$ | 15.1      |    5.1 |
#
# What ratio do you need to mix basalt and harzburgite back together to get the composition of the mantle before melt was removed? Assumptions:
#
# - Pyrolite is a combination of melt (basalt) and melted mantle (harzburgites)
# - Earth has the same Refractory Lithophile Elemental (RLE) abundances as Chondrites

# %% [markdown]
# Solution.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L5_S36_F0.svg" style='height:700px'/></center>

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/jagoutz.png" style='height:650px'>
#     </div>
# </center>
# <p></p>
