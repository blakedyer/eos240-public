# %% [markdown]
# Lecture 1: Course introduction

# %%
import numpy as np
from IPython.core.display import HTML
from matplotlib import pyplot as plt

# %%
nb_list = !jupyter notebook list
server = [l for l in nb_list if 'eos240' in l][0].split(' :: ')[0]
prefix = server.split('?')[0]
token = server.split('?')[1]
notebook = 'Lecture01.ipynb'
url = prefix+'notebooks/'+notebook+'?'+token
# !decktape -s '1920x1080' rise $url pdf_slides/Lecture01.pdf
# Out:
# Loading page http://localhost:8889/notebooks/Lecture01.ipynb?token=2c9a886584e852f7fe5cd5f11c7b5a1c5da28b7fe03dd7a3 ...
# actions jupyter-notebook:find-and-replace does not exist, still binding it in case it will be defined later...
# load_extensions {
#   '0': 'nbextensions_configurator/config_menu/main',
#   '1': 'contrib_nbextensions_help_item/main',
#   '2': 'rise/main',
#   '3': 'jupyter-js-widgets/extension',
#   '4': 'jupyter-black-master/jupyter-black',
#   '5': 'toc2/main',
#   '6': 'hide_code/hide_code',
#   '7': 'hide_input/main',
#   '8': 'codefolding/main',
#   '9': 'splitcell/splitcell'
# }
# Loaded moment locale en-gb
# HTML Sanitizer style removed { change: 'removed', tagName: 'style' }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'background: url(images/andromeda.jpg) 50% 60% no-repeat;\n' +
#     '  width: 1290px;\n' +
#     '  height: 181px; background-size: 100%;',
#   newValue: 'background: url("images/andromeda.jpg") 50% 60% no-repeat ; width: 1290px ; height: 181px ; background-size: 100%'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'font-size:25px',
#   newValue: 'font-size: 25px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'font-size:25px',
#   newValue: 'font-size: 25px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:50vh',
#   newValue: 'height: 50vh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:firebrick',
#   newValue: 'color: firebrick'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-size:3em',
#   newValue: 'font-size: 3em'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:firebrick',
#   newValue: 'color: firebrick'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:dodgerblue',
#   newValue: 'color: dodgerblue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:dodgerblue',
#   newValue: 'color: dodgerblue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:80vh;',
#   newValue: 'height: 80vh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'visibility:hidden;height:700px',
#   newValue: 'visibility: hidden ; height: 700px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:80vh;',
#   newValue: 'height: 80vh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-size:25px',
#   newValue: 'font-size: 25px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:750px;',
#   newValue: 'height: 750px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:750px',
#   newValue: 'height: 750px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:DodgerBlue',
#   newValue: 'color: dodgerblue'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:750px',
#   newValue: 'height: 750px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:562px',
#   newValue: 'height: 562px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:400px;',
#   newValue: 'height: 400px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:400px',
#   newValue: 'height: 400px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-size:25px',
#   newValue: 'font-size: 25px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:750px;',
#   newValue: 'height: 750px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:750px',
#   newValue: 'height: 750px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:650px;',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:650px',
#   newValue: 'height: 650px'
# }
# Failed to load resource: the server responded with a status of 404 (Not Found)
# Loading extension: nbextensions_configurator/config_menu/main
# Session: kernel_created (968188fb-e7dd-4daf-8189-c7a5fc3f8765)
# Starting WebSockets: ws://localhost:8889/api/kernels/ecb14771-5fbc-4f3a-acb0-01d984053e7f
# Failed to load extension: [ 'nbextensions/hide_code/hide_code' ] {
#   requireType: 'scripterror',
#   requireModules: [ 'nbextensions/hide_code/hide_code' ],
#   originalError: { isTrusted: true }
# }
# Loading extension: splitcell/splitcell
# center
# center
# center
# Loading extension: contrib_nbextensions_help_item/main
# Loading extension: rise/main
# Loading extension: hide_input/main
# Kernel: kernel_connected (ecb14771-5fbc-4f3a-acb0-01d984053e7f)
# Loading extension: jupyter-js-widgets/extension
# Failed to load resource: the server responded with a status of 404 (Not Found)
# Widgets are not available.  Please install widgetsnbextension or ipywidgets 4.0
# Loading extension: codefolding/main
# Loading extension: jupyter-black-master/jupyter-black
# Loading extension: toc2/main
# [toc2] Notebook fully loaded -- toc2 initialized
# Loading page finished with status: 200
# RISE plugin activated
# Refused to apply style from 'http://localhost:8889/notebooks/Lecture01.css' because its MIME type ('text/html') is not a supported stylesheet MIME type, and strict MIME checking is enabled.
# Failed to load resource: the server responded with a status of 404 (Not Found)
# Failed to get file none.json. ReadyState: 4, Status: 404
# Codefolding: Wait for 1000 ms
# Printing slide #/slide-18-0 (25/19) ...
# Printed 25 slides

# %% [markdown]
# HTML(
#     """
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# .jp-RenderedImage {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# .prompt
#     display:none;
# </style>
# """
# )

# %% [markdown]
# <center><div style="background: url(images/andromeda.jpg) 50% 60% no-repeat;
#   width: 1290px;
#   height: 181px; background-size: 100%;">
# </div></center>

# %% [markdown]
# # Lecture 1: Course introduction
# <div style='font-size:25px'>
#
# 1. Introductions
#     1. Who am I?
#     1. Who are you?
# 1. Course structure
# 1. Geochemistry
#     1. What does it mean?
#     1. What can it tell us?
#     1. What are the tools of the trade?
# 1. Making the Earth
#     1. Chemical composition of the solar system
#
# </div>

# %% [markdown]
# <div style='font-size:25px'> <i>We acknowledge and respect the lək̓ʷəŋən peoples on whose traditional territory the university stands and the Songhees, Esquimalt and W̱SÁNEĆ peoples whose historical relationships with the land continue to this day. </i></div>

# %% [markdown]
# ## Who am I?
#
# - Blake Dyer (he/him/his)
#     - I prefer Blake over Dr. Dyer or Professor Dyer
# - Undergraduate at Rice University 2006-2010
# - PhD at Princeton University 2010-2015
# - Postdoc at LDEO (Columbia University) 2016-2019
# - Started in SEOS at UVic in Nov 2019
# - Seventh time teaching EOS 240
#     - Also teach Advanced Sed/Strat (EOS 423), Marine Geology (EOS 408), and The Dynamic Earth (EOS 120)

# %% [markdown]
# ## Research interests: the geologic history of climate and life
#
# <center>
# 	    <img src="images/honaker_snow.jpg" style='height:700px'>
# </center>

# %% [markdown]
# ## Research interests: the geologic history of climate and life
#
# <center>
# 	    <img src="images/bahamas_work.jpg" style='height:700px'>
# </center>

# %% [markdown]
# ## Who are you?
#
# - Name
#
# and some optional prompts:
#
# - What is something you find interested about Earth Science?
# - What program are you in and/or why?
# - What do you hope to learn in EOS 240?
# - What challenges do you anticipate?

# %% [markdown]
# ## Course Outline, Brightspace, and Course Webpage
# <br><br>
# <div style='height:50vh'>
#
# [Brightspace](https://bright.uvic.ca/): All important announcements, assignments, and grades will be managed through Brightspace.
#
# [Course Webpage](https://eos-courses.readthedocs.io/en/latest/eos240-public/overview.html): Lecture slides and other course materials can be found on the course webpage, updated shortly after each class. There is a link to this page under Course Materials on Brightspace.
#
#
#
#
# <br><br>
# <center><span style='color:firebrick'><i>Go through course outline</i></span>    </center>
#
# </div>

# %% [markdown]
# ## Geochemistry: what does it mean?
# <p></p>

# %% [markdown]
# <center><span style='font-size:3em'>geology + chemistry</span></center>

# %% [markdown]
# In geochemistry, we use the <span style='color:firebrick'>**tools**</span> of chemistry to solve geological problems. In other words, we use chemistry to understand the <span style='color:dodgerblue'>**Earth**</span> and how it works.

# %% [markdown]
# <span style='color:dodgerblue'>**Earth**</span> doesn't limit us to *just* Earth, as understanding the *origins* and *history* of Earth means we also study meteorites, stars, other planets, etc.

# %% [markdown]
# ## Geochemistry: what can it tell us?
# <p></p>

# %% [markdown]
# - quantify the geologic timescale
# - depth and temperature of magma chambers
# - that sediments are subducted into the mantle
# - the temperature and pressure that metamorphic rocks form at, and as one example this knowledge can help determine the displacement along faults
# - how fast mountain belts have risen
# - how fast mountain belts are eroding
# - how and when the crust formed
# - how the mantle convects
# - how cold the ice ages were and what caused them
# - when life began on Earth
# - the impact and causes of acid rain, the ozone hole, greenhouse effect, and global warming
# - sources and solutions to environmental contamination

# %% [markdown]
# ## Geochemistry: what are the *tools* of the trade?
# <p></p>

# %% [markdown]
# - physical tools such as intruments that make chemical measurements
# - chemical experiments
# - interpretive tools (models) that explain observations
#     - primarily based in thermodynamics, but can include kinetics, aquatic chemistry, trace element geochemistry, isotope geochemistry

# %% [markdown]
# ## Thermodynamics: why is thermodynamics useful to a geochemist?
# <p></p>

# %% [markdown]
# - thermodynamics allows us to predict the outcome of chemical reactions under a given set of conditions
#     - predict the sequence of minerals that will crystallize from a magma
#     - may seem purely academic except that we can use this predictive power to work backwards: can determine the temperature, pressure, and composition of the magma or water from which minerals crystallized
#         - allows us to understand how Earth has come to its present condition

# %% [markdown]
# Schematic of Earth.
# <center>
#     <div style='height:80vh;'>
# 	    <img src="chalkboard_images/L1_S6_F0.svg" style='visibility:hidden;height:700px'/>
#     </div>
# </center>

# %% [markdown]
# Schematic of Earth.
# <center>
#     <div style='height:80vh;'>
# 	    <img src="chalkboard_images/L1_S6_F0.svg" style='height:700px'/>
#     </div>
# </center>

# %% [markdown]
# <center>
#     <span style='font-size:25px'>What is the chemical composition of Earth?</span>
#     <br>
#     <br>
#     <div style='height:750px;'>
# 	    <img src="images/earth.png" style='height:750px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
# 	    <img src="images/xenolith.jpg" style='height:700px'>
# </center>
# <p></p>

# %% [markdown]
# <center><span style='color:DodgerBlue'><b>What is the black rock? What are the green bits?</b></span></center>

# %% [markdown]
# <center>
# 	    <img src="images/nebula1.jpg" style='height:750px'>
# </center>
# <p></p>

# %% [markdown]
# <center>
# 	    <img src="images/disk.jpg" style='height:562px'>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <div style='height:400px;'>
# 	    <img src="images/temp_disk.jpg" style='height:400px'>
#     </div><br>
#         <span style='font-size:25px'>
# The hot disk begins to emit radiation to space, rapidly cools, and a temperature gradient develops.</span><br>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <div style='height:750px;'>
# 	    <img src="images/Solar-System.jpg" style='height:750px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/solar_abundance.png" style='height:650px'>
#     </div>
# </center>
# <p></p>
