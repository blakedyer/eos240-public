# %% [markdown]
# Lectures 1-5: the chemical composition of Earth

# %%
import numpy as np
from IPython.core.display import HTML
from matplotlib import pyplot as plt

# %%
nb_list = !jupyter notebook list
server = [l for l in nb_list if 'eos240' in l][0].split(' :: ')[0]
prefix = server.split('?')[0]
token = server.split('?')[1]
notebook = 'Lecture01.ipynb'
url = prefix+'notebooks/'+notebook+'?'+token
# !decktape -s '1920x1080' rise $url pdf_slides/Lecture01.pdf
# Out:
# Loading page http://localhost:8888/notebooks/Lecture01.ipynb?token=157aac4cd3d1483056be832543425062f4433f9dc075afda ...
# actions jupyter-notebook:find-and-replace does not exist, still binding it in case it will be defined later...
# load_extensions {
#   '0': 'nbextensions_configurator/config_menu/main',
#   '1': 'contrib_nbextensions_help_item/main',
#   '2': 'rise/main',
#   '3': 'jupyter-js-widgets/extension',
#   '4': 'jupyter-black-master/jupyter-black',
#   '5': 'toc2/main',
#   '6': 'hide_code/hide_code',
#   '7': 'hide_input/main',
#   '8': 'codefolding/main',
#   '9': 'splitcell/splitcell'
# }
# Loaded moment locale en-gb
# Failed to load resource: the server responded with a status of 404 (Not Found)
# HTML Sanitizer style removed { change: 'removed', tagName: 'style' }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'background: url(images/andromeda.jpg) 50% 60% no-repeat;\n' +
# ...

# %% [markdown]
# HTML(
#     """
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# .jp-RenderedImage {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# .prompt
#     display:none;
# </style>
# """
# )

# %% [markdown]
# <center><div style="background: url(images/andromeda.jpg) 50% 60% no-repeat;
#   width: 1290px;
#   height: 181px; background-size: 100%;">
# </div></center>

# %% [markdown]
# # Lectures 1-5: the chemical composition of Earth
# <div style='font-size:25px'>
#
# 1. Introductions
#     1. Who am I?
#     1. Who are you?
# 1. Course structure
# 1. Making the Earth
#     1. Chemical composition of the solar system
#     1. Refractory and volatile elements
#     1. Lithophile and Siderophile
# 1. Primitive Mantle
#     1. Melting Olivine
#     1. Pyrolite model
#
# </div>

# %% [markdown]
# <div style='font-size:25px'> <i>We acknowledge and respect the lək̓ʷəŋən peoples on whose traditional territory the university stands and the Songhees, Esquimalt and W̱SÁNEĆ peoples whose historical relationships with the land continue to this day. </i></div>

# %% [markdown]
# ## Who am I?
#
# <span style='font-size:25px'>
#
# - Blake Dyer (he/him/his)
#     - I prefer Blake over Dr. Dyer or Professor Dyer
#
# </span>

# %% [markdown]
# <span style='font-size:25px'>
#
# - Undergraduate at Rice University 2006-2010
#
# </span>

# %% [markdown]
# <span style='font-size:25px'>
#
# - PhD at Princeton University 2010-2015
#
# </span>

# %% [markdown]
# <span style='font-size:25px'>
#
# - Postdoc at LDEO (Columbia University) 2016-2019
#
# </span>

# %% [markdown]
# <span style='font-size:25px'>
#
# - Started in SEOS at UVic in Nov 2019
#
# </span>

# %% [markdown]
# <span style='font-size:25px'>
#
# - Fifth time teaching EOS 240
#     - Also teach Advanced Sed/Strat, Marine Geology, and The Dynamic Earth
#
# </span>

# %% [markdown]
# ## Research interests: the geologic history of climate and life
#
# <center>
# 	    <img src="images/honaker_snow.jpg" style='height:700px'>
# </center>

# %% [markdown]
# ## Research interests: the geologic history of climate and life
#
# <center>
# 	    <img src="images/bahamas_work.jpg" style='height:700px'>
# </center>

# %% [markdown]
# ## Who are you?
#
# Some optional prompts:
# - Name
# - Why are you here?
#     - What program are you in and/or why?
#     - What do you hope to learn in EOS 240?
#     - What challenges do you anticipate?

# %% [markdown]
# ## Geochemistry: a *toolset* for investigating Earth systems
# <p></p>

# %% [markdown]
# 1. How and when did the Earth form?

# %% [markdown]
# 2. What about the continents?

# %% [markdown]
# 3. When did life on Earth begin?

# %% [markdown]
# 4. How has climate changed in the past?

# %% [markdown]
# 5. Where should we look for habitable planets?

# %% [markdown]
# Schematic of Earth.
# <center>
#     <div style='height:80vh;'>
# 	    <img src="chalkboard_images/L1_S6_F0.svg" style='height:700px'/>
#     </div>
# </center>

# %% [markdown]
# <center>
#     <span style='font-size:25px'>What is the chemical composition of Earth?</span>
#     <br>
#     <br>
#     <div style='height:750px;'>
# 	    <img src="images/earth.png" style='height:750px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
# 	    <img src="images/xenolith.jpg" style='height:700px'>
# </center>
# <p></p>

# %% [markdown]
# <center><span style='color:DodgerBlue'><b>What is the black rock? What are the green bits?</b></span></center>

# %% [markdown]
# <center>
# 	    <img src="images/nebula1.jpg" style='height:750px'>
# </center>
# <p></p>

# %% [markdown]
# <center>
# 	    <img src="images/disk.jpg" style='height:562px'>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <div style='height:400px;'>
# 	    <img src="images/temp_disk.jpg" style='height:400px'>
#     </div><br>
#         <span style='font-size:25px'>
# The hot disk begins to emit radiation to space, rapidly cools, and a temperature gradient develops.</span><br>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <div style='height:750px;'>
# 	    <img src="images/Solar-System.jpg" style='height:750px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/solar_abundance.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L2_S12_F-1.svg" style='height:700px'/></center>

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/solar_abundance.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center><span style='font-weight:600;color:DodgerBlue'>What are the major rock forming elements on Earth?</span></center>
# <p></p>

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/solar_abundance.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <span style='font-weight:600;color:DodgerBlue'>Earth $\approx$ MgO + CaO + SiO$_2$ + Al$_2$O$_3$ + FeO</span>
# </center>

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/solar_abundance.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <span style='font-weight:600;color:DodgerBlue'>Should the Sun and Earth have the same chemistry? How could we check?</span>
# </center>

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/ci_vs_solar.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# ### Planetary Formation
#
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L3_S20_F0.svg" style='height:700px'/></center>

# %% [markdown]
# ### Condensation sequence calculations
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L2_S17_F0.svg" style='height:700px'/></center>

# %% [markdown]
# ### Condensation sequence calculations
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L3_S18_F0.svg" style='height:700px'/></center>

# %%
#1 atm =  101325 pa (per gfw is same as per mol)
#joule is pa m^3
# Out:
# -1581895088

# %%
DONT FORGET TO BRING UP ROUND UP

# %%
import numpy as np
# g = -RT ln Q
Al_n=8.51*10**4
O_n=2.36*10**7
H_n=2.6*10**10
P_total=10**(-3)#*101325 #assume all H2 convert to pascals for gas constant
#pv=NRT
Al_p = Al_n/(2*H_n)*P_total
O_p = O_n/(2*H_n)*P_total
Q = 1/(Al_p**2*O_p**3)
# X=(0.99*Al_p)*0.5
# Q2 = 1/((Al_p-2*X)**2*(O_p-3*X)**3)
R = 8.314 #J/mK
# R = 0.730240507295273
# dg = -R*1758*np.log(Q)
dg = (-378082*4184)
dg/(-R*np.log(Q))
# Out:
# 25703846.26942203

# %%
from matplotlib import pyplot as plt
#DG=-RTlogK
T = np.linspace(1500,2000,100)
# R = 8.314
R = 0.730240507295273

R_Al=8.51*10**4
R_O=2.36*10**7
R_H=2.6*10**10

P_total = 10**-3
P_h2 = P_total
P_h = 2/1 * P_h2
P_Al = R_Al/R_H*P_h*0.77 ##77% of Al is Al gas
P_O = R_O/R_H*P_h*0.000016 ## .0015% of O is O gas, most H2O
DG = 1679485.0250000001
Rgc  = 8.3144621
logK = DG/(-Rgc*T)

neb = np.log(P_Al**2*P_O**3)
plt.plot(T,[neb]*T.size)

plt.plot(T,logK)


## can shift to match old literature if using log10 for both the dg/rt calc and on the vapor

# %%
2*np.log10(P_Al)+3*np.log10(P_O)
# Out:
# -48.20578023414195

# %%
np.log10(P_Al**2*P_O**3)
# Out:
# -48.20578023414195

# %%
-1581970.4 J/mol Al2O3
# Out:
# 55000.0

# %%
1581970+1263000
# Out:
# 2844970

# %%
91416*R*101325
# Out:
# 6764017879.225216

# %%
- 8.314 * 1758 * -52
# Out:
# 760032.6240000001

# %%
Nal = Ax/Ah*Nt

# %% [markdown]
# ### Practice Problem: Condensation of Corundum from the Solar Nebula
# **Q1**: Calculate the temperature that Corundum (Al$_2$O$_3$) begins condensing from the solar nebula using the following values (assume no other reactions):
#
# $$ \mathrm{2Al + 3O \leftrightarrow Al_2O_3} $$
#
# - Solar abundance (atoms) of Al: 8.51 x 10$^4$
# - Solar abundance (atoms) of O: 2.36 x 10$^7$
# - Solar abundance (atoms) of H: 2.6 x 10$^{10}$
# - Pressure in the nebula: 10$^{-3}$ atm
# - Gas constant (R): 8.314 J/mol K
# - $\Delta$G$^\circ$ (standard free energy of reaction) for condensation of Al$_2$O$_3$: -1.23 x 10$^6$ J/mol
#
# **Q2**: At what temperature will this reaction finish condensing all of the Aluminum in the nebula?

# %% [markdown]
# <center>
#     <div style='height:800px;'>
# 	    <img src="images/condensation.png" style='height:800px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <span style='font-weight:600;color:DodgerBlue'>Recall: Earth $\approx$ MgO + CaO + SiO$_2$ + Al$_2$O$_3$ + FeO</span>
# </center>

# %%
from IPython.display import HTML

HTML(
    """
<center>
<div align="middle;height:10vh;">
<video width="60%" controls>
      <source src="videos/planet_formation.mp4" type="video/webm">
</video></div></center>"""
)
# Out:
# <center>
# <div align="middle;height:10vh;">
# <video width="60%" controls>
#       <source src="videos/planet_formation.mp4" type="video/webm">
# </video></div></center>

# %% [markdown]
# ### Solar abundance model for major element Earth chemistry
# The observed solar abundance for each major rock forming element is:
#
# | Element        | Solar abundance (atoms)           | Atomic Mass (g)  |
# | ------------- |:-------------:| -----:|
# | Mg      | 104 | 24.3 |
# | Si      | 100      |   28.1 |
# | Ca | 6.2     |    40.1 |
# | Fe | 86     |    55.8 |
# | Al | 8.4      |    27 |
# | O |        |    16 |
#
# Assume 100% of Earth's mass $=$ MgO + CaO + SiO$_2$ + Al$_2$O$_3$ + FeO
#
# What is the weight % of MgO in Bulk Earth (before core formation)?

# %% [markdown]
# <center><img src="chalkboard_images/L3_S22_F0.svg" style='height:700px'/></center>

# %% [markdown]
# <center><img src="chalkboard_images/L3_S23_F0.svg" style='height:700px'/></center>

# %% [markdown]
# Follow up: **What if you move all of the Fe into a core? What is the new MgO wt% in the remaining mantle?**
# <center>
#     <div style='height:60vh;'>
# 	    <p>
#     </div>
# </center>

# %%
Mg = 24.3
Si = 28.1
Ca = 40.1
Fe = 55.8
Al = 27
O = 16

MgO = Mg + O
SiO2 = Si + 2 * O
Al2O3 = Al * 2 + O * 3
CaO = Ca + O
FeO = Fe + O

(104 * MgO) / (104 * MgO + 100 * SiO2 + 0.5 * 8.4 * Al2O3 + 6.2 * CaO + 86 * FeO) * 100
# Out:
# 24.43532090889692

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.figure(figsize=(10,10))
frac = np.linspace(0, 1, 100)
total_M = 104 * MgO + 100 * SiO2 + 0.5 * 8.4 * Al2O3 + 6.2 * CaO + (1 - frac) * 86 * FeO

plt.plot(frac, (104 * MgO) / total_M * 100, label="MgO")
plt.plot(frac, (1 - frac) * 86 * FeO / total_M * 100, label="FeO")
plt.gca().set_xlabel("Fraction of FeO removed to Core")
plt.gca().set_ylabel("Wt % Oxide")
plt.legend()

# %% [markdown]
# <center>
#     <div style='height:450px;'>
# 	    <img src="images/solar_model.png" style='height:450px'>
#     </div>
# </center>

# %% [markdown]
# <span style='font-weight:600;color:DodgerBlue'>Define Goldschmidt classification.</span><p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L3_S27_F0.svg" style='height:700px'/></center>

# %% [markdown]
# <span style='font-weight:600;color:DodgerBlue'>Define Goldschmidt classification.</span><p></p>

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/RLE.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <div style='height:780px;'>
# 	    <img src="images/condensation_phase.jpg" style='height:780px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# add PM/CI abundance vs condensation figure next year

# %% [markdown]
# <span style='font-weight:600;color:DodgerBlue'>Define Primitive Mantle. What do we know about the modern mantle?</span><br>
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L4_S28_F0.svg" style='height:700px'/></center>

# %% [markdown]
# Olivine Solid Solution Phase Diagram.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L4_S29_F0.svg" style='height:700px'/></center>

# %% [markdown]
# Melting trends.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L4_S30_F0.svg" style='height:700px'/></center>

# %% [markdown]
# <center><img src="chalkboard_images/L5_S31_F0.svg" style='height:700px'/></center>
#
#
#
# **Pyrolite Model**: Ringwood, A.E., 1962. **A model for the upper mantle**. *Journal of Geophysical Research*.

# %% [markdown]
# Chondrites
#
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/cai.jpg" style='height:550px'>
#     </div>
# </center>
#
# <p></p>

# %% [markdown]
# Chondrules: molten 'droplets' of nebular dust
#
# AOAs: Ameboidal Olivine Aggregates ~100% olivine
#
# CAIs: Calcium Aluminum Inclusions are the first condensates

# %% [markdown]
# Mineralogy of Chondrite phases
#
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/chondrite_phases.jpg" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# Chondrites have variable composition
#
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/mg_si_chond.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# ### Practice problem
# The observed chondritic mass abundances for Calcium and Aluminum are:
#
# | Element        | wt % in Chondrite           | Atomic Mass  |
# | ------------- |:-------------:| -----:|
# | Ca | 0.92     |    40.1 |
# | Al | 0.85      |    27 |
#
# The average wt % of CaO and Al$_2$O$_3$ in Basalt and Harzburgite:
#
# | **Oxide**        | wt % in Basalt           | wt % in Harzburgite   |
# | ------------- |:-------------:| -----:|
# | CaO | 11.3     |   6.1 |
# | Al$_2$O$_3$ | 15.1      |    5.1 |
#
# What ratio do you need to mix basalt and harzburgite back together to get the composition of the mantle before melt was removed? Assumptions:
#
# - Pyrolite is a combination of melt (basalt) and melted mantle (harzburgites)
# - Earth has the same Refractory Lithophile Elemental (RLE) abundances as Chondrites

# %% [markdown]
# Solution.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L5_S35_F0.svg" style='height:700px'/></center>

# %% [markdown]
# Solution.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L5_S36_F0.svg" style='height:700px'/></center>

# %% [markdown]
# First, solve for the CaO to Al$_2$O$_3$ ratio in chondrites. \
# (Ca/40.1x(40.1+16))/(Al/27x.5x(27x2+16x3))
# 0.802 CaO:Al2O3
#
# Now mass balance:
# a=.115
# b=1-a
# ax1.2 + bx.75 = 0.8 where 1.2 is the ratio in Harz and 0.75 is the ratio in basalt

# %%
.92/40.1*(40.1+16)
# Out:
# 1.2870822942643392

# %%
.85/27*(1/2)*(27*2+16*3)
# Out:
# 1.6055555555555554

# %%
1.2870822942643392/1.6055555555555554
# Out:
# 0.8016429514449173

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/jagoutz.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <div style='height:60vh;'>
# 	    <p>
#     </div>
# </center>

# %%
Ca = 0.0092
Al = 0.0085
Ca / Al

# %%
Mg = 95800 / 1e6

# %%
dunite = 1.7 ca and 2.3 al
basalt = 11.3 ca and 15.1 al

0.0605398406374502 CAO HARZ
0.0507625 AL2O3 HARZ

# %%
0.0605398406374502 / 0.0507625

# %%
11.3 / 15.1

# %%
a = 0.115
b = 1 - a
a * 1.2 + b * 0.75

# %%
# import pandas as pd
# basalt = pd.read_csv('Lecture 3/BASALT_part1.csv',skiprows=0)
# dunite = pd.read_csv('Lecture 3/DUNITE.csv',skiprows=0)
# lherz = pd.read_csv('Lecture 3/LHERZOLITE.csv',skiprows=0)
# CaAl = lherz[['CAO(WT%)','AL2O3(WT%)']].dropna().values
# fig=plt.figure(figsize=(15,6))
# # plt.subplot(1,2,1)
# plt.plot(CaAl[:,0],CaAl[:,1],'.',label='CaO (wt%)',alpha=.5)
# plt.gca().set_xlim(34,44)
# plt.gca().set_ylim(0,7)

# plt.gca().set_xlabel('MgO (wt%)')
# plt.gca().set_ylabel('CaO (wt%)')

# plt.subplot(1,2,2)
# plt.plot([])
# plt.plot(AlMg[:,1],,'.',label='Al2O3 (wt%)',alpha=.5)
# plt.gca().set_xlim(34,44)
# plt.gca().set_ylim(0,7)

# plt.gca().set_xlabel('MgO (wt%)')
# plt.gca().set_ylabel('Al2O3 (wt%)')
# fig.suptitle('Lherzolites')

# %%
import json

# %%
from matplotlib import pyplot as plt

# %%
a = json.load(open('chalkboard.json',))

# %%
xs = [ff['x'] for ff in a[0]['data'][0]['events'][1]['curve']]
ys = [ff['y'] for ff in a[0]['data'][0]['events'][1]['curve']]

# %%
plt.plot(xs,ys)

# %%
import seaborn as sns
Lecture_Number=10
a = json.load(open(f'chalkboard/2022/EOS240-Lecture{Lecture_Number}.json',))
colors = sns.color_palette("deep")
colors_resorted = [7,9,3,2,1,4,8]
colors = [colors[a] for a in colors_resorted]    
ratio = a[0]['width']/a[0]['height']

# %%
# %%capture

for slide in a[0]["data"]:
    fig = plt.figure(figsize=(5 * ratio, 5))
    Slide_Number = slide["slide"]["h"]
    if "f" in slide["slide"].keys():
        Fragment_Number = slide["slide"]["f"]
    else:
        Fragment_Number = 0
    for k in slide["events"]:
        if k["type"] == "setcolor":
            color = colors[k["index"]]
        elif k["type"] == "draw":
            xs = [nnn["x"] for nnn in k["curve"]]
            ys = [nnn["y"] for nnn in k["curve"]]
            plt.plot(xs, -1 * np.array(ys), lw=1, color=color)
    plt.gca().set_aspect("equal")
    plt.axis("off")
    fig.savefig(
        f"chalkboard_images/L{Lecture_Number}_S{Slide_Number}_F{Fragment_Number}.svg",
        facecolor="white",
        transparent=False,
        bbox_inches="tight",
        dpi=300,
    )

# %%
# %%capture
import seaborn as sns
lectures = [1,2,3,4,5,6,8,9,10,11,12,13,14,16,17,18,19,20,21]
for Lecture_Number in lectures:
    a = json.load(open(f'chalkboard/2022/EOS240-Lecture{Lecture_Number}.json',))
    colors = sns.color_palette("deep")
    colors_resorted = [7,9,3,2,1,4,8]
    colors = [colors[a] for a in colors_resorted]    
    ratio = a[0]['width']/a[0]['height']

    for slide in a[0]["data"]:
        fig = plt.figure(figsize=(5 * ratio, 5))
        Slide_Number = slide["slide"]["h"]
        if "f" in slide["slide"].keys():
            Fragment_Number = slide["slide"]["f"]
        else:
            Fragment_Number = 0
        for k in slide["events"]:
            if k["type"] == "setcolor":
                color = colors[k["index"]]
            elif k["type"] == "draw":
                xs = [nnn["x"] for nnn in k["curve"]]
                ys = [nnn["y"] for nnn in k["curve"]]
                plt.plot(xs, -1 * np.array(ys), lw=1, color=color)
        plt.gca().set_aspect("equal")
        plt.axis("off")
        fig.savefig(
            f"chalkboard_images/L{Lecture_Number}_S{Slide_Number}_F{Fragment_Number}.svg",
            facecolor="white",
            transparent=False,
            bbox_inches="tight",
            dpi=300,
        )

# %%
slide_n = 4
x
fig=plt.figure(figsize=(5*ratio,5))
for k in a[0]['data'][slide_n]['events']:
    if k['type']=='setcolor':
        color=colors[k['index']]
    elif k['type']=='draw':
            xs = [nnn['x'] for nnn in k['curve']]
            ys = [nnn['y'] for nnn in k['curve']]
            plt.plot(xs,-1*np.array(ys),lw=.5,color=color)
# plt.gca().set_xlim(0,a[0]['width'])
# plt.gca().set_ylim(-a[0]['height'],0)
plt.gca().set_aspect("equal")
plt.axis('off')
fig.savefig(f"chalkboard_images/L{LectureNumber}_S{SlideNumber}_F{Fragment_Number}.svg", facecolor='white', transparent=False, bbox_inches='tight')

# %%
# Out:
# {'width': 1280, 'height': 609, 'data': []}

# %%
shapes = [ff['curve'] for ff in a[0]['data'][1]['events'] for k in ff if ff['type']=='draw']
import numpy as np
fig=plt.figure(figsize=(12,8))
for i in range(len(shapes)):
    xs = [k['x'] for k in shapes[i]]
    ys = [k['y'] for k in shapes[i]]
    plt.plot(xs,-1*np.array(ys),lw=1,color='k')
    
plt.gca().set_ylim(-981,0)
plt.gca().set_xlim([0,1832])
# Out:
# (0.0, 1832.0)

# %%
shapes = [ff['curve'] for ff in a[0]['data'][1]['events'] for k in ff if ff['type']=='draw']
import numpy as np
fig=plt.figure(figsize=(12,8))
for i in range(len(shapes)):
    xs = [k['x'] for k in shapes[i]]
    ys = [k['y'] for k in shapes[i]]
    plt.plot(xs,-1*np.array(ys),lw=1,color='k')
    
plt.gca().set_ylim(-981,0)
plt.gca().set_xlim([0,1832])
# Out:
# (0.0, 1832.0)

# %%
a[0]['data'][3]['events'][1]
# Out:
# {'type': 'draw',
#  'begin': 58906,
#  'end': 59617,
#  'curve': [{'x': 208.9625, 'y': 205.20416666666665},
#   {'x': 208.9625, 'y': 205.20416666666665},
#   {'x': 208.9625, 'y': 205.20416666666665},
#   {'x': 208.9625, 'y': 205.20416666666665},
#   {'x': 208.9625, 'y': 204.25},
#   {'x': 208.00833333333333, 'y': 204.25},
#   {'x': 205.14583333333334, 'y': 204.25},
#   {'x': 200.375, 'y': 204.25},
#   {'x': 200.375, 'y': 204.25},
#   {'x': 196.55833333333334, 'y': 204.25},
#   {'x': 193.69583333333333, 'y': 205.20416666666665},
#   {'x': 189.87916666666666, 'y': 207.11249999999998},
#   {'x': 187.01666666666668, 'y': 209.02083333333331},
#   {'x': 184.15416666666667, 'y': 211.88333333333333},
#   {'x': 181.29166666666666, 'y': 219.51666666666665},
#   {'x': 181.29166666666666, 'y': 223.33333333333331},
#   {'x': 182.24583333333334, 'y': 226.19583333333333},
#   {'x': 189.87916666666666, 'y': 234.78333333333333},
#   {'x': 200.375, 'y': 239.55416666666667},
# ...

# %%
a[0]['data'][3]['events']
# Out:
# [{'type': 'setcolor', 'index': 0, 'begin': 24892},
#  {'type': 'draw',
#   'begin': 58906,
#   'end': 59617,
#   'curve': [{'x': 208.9625, 'y': 205.20416666666665},
#    {'x': 208.9625, 'y': 205.20416666666665},
#    {'x': 208.9625, 'y': 205.20416666666665},
#    {'x': 208.9625, 'y': 205.20416666666665},
#    {'x': 208.9625, 'y': 204.25},
#    {'x': 208.00833333333333, 'y': 204.25},
#    {'x': 205.14583333333334, 'y': 204.25},
#    {'x': 200.375, 'y': 204.25},
#    {'x': 200.375, 'y': 204.25},
#    {'x': 196.55833333333334, 'y': 204.25},
#    {'x': 193.69583333333333, 'y': 205.20416666666665},
#    {'x': 189.87916666666666, 'y': 207.11249999999998},
#    {'x': 187.01666666666668, 'y': 209.02083333333331},
#    {'x': 184.15416666666667, 'y': 211.88333333333333},
#    {'x': 181.29166666666666, 'y': 219.51666666666665},
#    {'x': 181.29166666666666, 'y': 223.33333333333331},
#    {'x': 182.24583333333334, 'y': 226.19583333333333},
# ...

# %%
shapes = [ff['curve'] for ff in a[0]['data'][7]['events'] for k in ff if ff['type']=='draw']
import numpy as np
fig=plt.figure(figsize=(12,8))
for i in range(len(shapes)):
    xs = [k['x'] for k in shapes[i]]
    ys = [k['y'] for k in shapes[i]]
    plt.plot(xs,-1*np.array(ys),lw=1,color='k')
    
plt.gca().set_ylim(-981,0)
plt.gca().set_xlim([0,1832])
# Out:
# (0.0, 1832.0)

# %%
shapes = [ff['curve'] for ff in a[0]['data'][7]['events'] for k in ff if ff['type']=='draw']
import numpy as np
fig=plt.figure(figsize=(12,8))
for i in range(len(shapes)):
    xs = [k['x'] for k in shapes[i]]
    ys = [k['y'] for k in shapes[i]]
    plt.plot(xs,-1*np.array(ys),lw=1,color='k')
    
plt.gca().set_ylim(-981,0)
plt.gca().set_xlim([0,1832])
# Out:
# {'slide': {'h': 13, 'v': 0, 'f': -1},
#  'events': [{'type': 'setcolor', 'index': 0, 'begin': 94233},
#   {'type': 'draw',
#    'begin': 170889,
#    'end': 172912,
#    'curve': [{'x': 673.6416666666667, 'y': 271.0416666666667},
#     {'x': 673.6416666666667, 'y': 270.0875},
#     {'x': 673.6416666666667, 'y': 270.0875},
#     {'x': 673.6416666666667, 'y': 269.1333333333333},
#     {'x': 673.6416666666667, 'y': 268.1791666666667},
#     {'x': 673.6416666666667, 'y': 268.1791666666667},
#     {'x': 673.6416666666667, 'y': 267.225},
#     {'x': 673.6416666666667, 'y': 267.225},
#     {'x': 673.6416666666667, 'y': 265.31666666666666},
#     {'x': 673.6416666666667, 'y': 264.3625},
#     {'x': 673.6416666666667, 'y': 264.3625},
#     {'x': 673.6416666666667, 'y': 262.45416666666665},
#     {'x': 673.6416666666667, 'y': 261.5},
#     {'x': 673.6416666666667, 'y': 260.54583333333335},
#     {'x': 673.6416666666667, 'y': 260.54583333333335},
# ...

# %%
import seaborn as sns
import numpy as np
for Lecture_Number in ["EOS240-Lecture8"]:
    a = json.load(open(f'chalkboard/2021/{Lecture_Number}.json',))
    colors = sns.color_palette("deep")
    colors_resorted = [7,9,3,2,1,4,8]
    colors = [colors[a] for a in colors_resorted] 
    color = colors[0]
    ratio = a[0]['width']/a[0]['height']

    for slide in a[0]["data"]:
        fig = plt.figure(figsize=(5 * ratio, 5))
        Slide_Number = slide["slide"]["h"]
        if "f" in slide["slide"].keys():
            Fragment_Number = slide["slide"]["f"]
        else:
            Fragment_Number = 0
        for k in slide["events"]:
            if k["type"] == "setcolor":
                color = colors[k["index"]]
            elif k["type"] == "draw":
                xs = [nnn["x"] for nnn in k["curve"]]
                ys = [nnn["y"] for nnn in k["curve"]]
                plt.plot(xs, -1 * np.array(ys), lw=1, color=color)
        plt.gca().set_aspect("equal")
        plt.axis("off")
        fig.savefig(
            f"chalkboard_images/L{Lecture_Number}_S{Slide_Number}_F{Fragment_Number}.svg",
            facecolor="white",
            transparent=False,
            bbox_inches="tight",
            dpi=300,
        )
