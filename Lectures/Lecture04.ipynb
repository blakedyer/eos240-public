# %% [markdown]
# Lecture 4: Condensation

# %%
nb_list = !jupyter notebook list
server = [l for l in nb_list if 'eos240' in l][0].split(' :: ')[0]
prefix = server.split('?')[0]
token = server.split('?')[1]
notebook = 'Lecture04.ipynb'
url = prefix+'notebooks/'+notebook+'?'+token
# !decktape -s '1920x1080' rise $url pdf_slides/Lecture04.pdf
# Out:
# Loading page http://localhost:8889/notebooks/Lecture04.ipynb?token=2c9a886584e852f7fe5cd5f11c7b5a1c5da28b7fe03dd7a3 ...
# actions jupyter-notebook:find-and-replace does not exist, still binding it in case it will be defined later...
# load_extensions {
#   '0': 'nbextensions_configurator/config_menu/main',
#   '1': 'contrib_nbextensions_help_item/main',
#   '2': 'rise/main',
#   '3': 'jupyter-js-widgets/extension',
#   '4': 'jupyter-black-master/jupyter-black',
#   '5': 'toc2/main',
#   '6': 'hide_code/hide_code',
#   '7': 'hide_input/main',
#   '8': 'codefolding/main',
#   '9': 'splitcell/splitcell'
# }
# Loaded moment locale en-gb
# Failed to load resource: the server responded with a status of 404 (Not Found)
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'background: url(images/andromeda.jpg) 50% 60% no-repeat;\n' +
#     '  width: 1290px;\n' +
#     '  height: 181px; background-size: 100%;',
#   newValue: 'background: url("images/andromeda.jpg") 50% 60% no-repeat ; width: 1290px ; height: 181px ; background-size: 100%'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'font-size:25px',
#   newValue: 'font-size: 25px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'font-size:25px',
#   newValue: 'font-size: 25px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:85vh;',
#   newValue: 'height: 85vh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:85vh',
#   newValue: 'height: 85vh'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:85vh;',
#   newValue: 'height: 85vh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:85vh',
#   newValue: 'height: 85vh'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:85vh;',
#   newValue: 'height: 85vh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:85vh',
#   newValue: 'height: 85vh'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:85vh;',
#   newValue: 'height: 85vh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:85vh',
#   newValue: 'height: 85vh'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:800px;',
#   newValue: 'height: 800px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:800px',
#   newValue: 'height: 800px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:dodgerblue',
#   newValue: 'color: dodgerblue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:700px;',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:800px',
#   newValue: 'height: 800px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-size:.7em',
#   newValue: 'font-size: 0.7em'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:dodgerblue',
#   newValue: 'color: dodgerblue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:700px;',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:800px',
#   newValue: 'height: 800px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-size:.7em',
#   newValue: 'font-size: 0.7em'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:800px;',
#   newValue: 'height: 800px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:800px',
#   newValue: 'height: 800px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:650px;',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:650px',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'font-weight:600;color:DodgerBlue',
#   newValue: 'font-weight: 600 ; color: dodgerblue'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:650px;',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:550px',
#   newValue: 'height: 550px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:650px;',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:650px',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:650px;',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:650px',
#   newValue: 'height: 650px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:700px',
#   newValue: 'height: 700px'
# }
# Failed to load extension: [ 'nbextensions/hide_code/hide_code' ] {
#   requireType: 'scripterror',
#   requireModules: [ 'nbextensions/hide_code/hide_code' ],
#   originalError: { isTrusted: true }
# }
# Loading extension: nbextensions_configurator/config_menu/main
# Session: kernel_created (e3000b8f-60ce-4060-b13d-2f3335b2e2bf)
# Starting WebSockets: ws://localhost:8889/api/kernels/ade330b8-b660-496b-8d57-d0631d3e2277
# Loading extension: hide_input/main
# Loading extension: splitcell/splitcell
# Loading extension: contrib_nbextensions_help_item/main
# Loading extension: rise/main
# Kernel: kernel_connected (ade330b8-b660-496b-8d57-d0631d3e2277)
# Loading extension: jupyter-js-widgets/extension
# Failed to load resource: the server responded with a status of 404 (Not Found)
# Widgets are not available.  Please install widgetsnbextension or ipywidgets 4.0
# Loading extension: codefolding/main
# Loading extension: jupyter-black-master/jupyter-black
# Loading extension: toc2/main
# [toc2] Notebook fully loaded -- toc2 initialized
# Access to font at 'about:blank' from origin 'http://localhost:8889' has been blocked by CORS policy: Cross origin requests are only supported for protocol schemes: http, data, chrome, chrome-untrusted, https.
#
# Unable to load resource from URL: about:blank
# Failed to load resource: net::ERR_FAILED
# Loading page finished with status: 200
# RISE plugin activated
# Refused to apply style from 'http://localhost:8889/notebooks/Lecture04.css' because its MIME type ('text/html') is not a supported stylesheet MIME type, and strict MIME checking is enabled.
# Codefolding: Wait for 1000 ms
# Failed to load resource: the server responded with a status of 404 (Not Found)
# Failed to get file none.json. ReadyState: 4, Status: 404
# Printing slide #/slide-4-0 (5/5) ...
# Printed 5 slides

# %% [markdown]
# <center><div style="background: url(images/andromeda.jpg) 50% 60% no-repeat;
#   width: 1290px;
#   height: 181px; background-size: 100%;">
# </div></center>

# %% [markdown]
# # Lecture 4: Condensation
# <div style='font-size:25px'>
#
# 1. Condensation of corundum
#
# <!-- 1. Condensation temperatures
#     1. Refractory vs volatile elements
# 1. Planet formation
# 1. Goldschmidt classification
# 1. The primitive mantle -->
#
# </div>

# %% [markdown]
# <div style='font-size:25px'> <i>We acknowledge and respect the lək̓ʷəŋən peoples on whose traditional territory the university stands and the Songhees, Esquimalt and W̱SÁNEĆ peoples whose historical relationships with the land continue to this day. </i></div>

# %% [markdown]
# ### Practice Problem: Condensation of Corundum from the Solar Nebula
# **Q1**: Calculate the temperature that Corundum (Al$_2$O$_3$) begins condensing from the solar nebula using the following values (assume no other reactions):
#
# $$ \mathrm{2Al + 3O \leftrightarrow Al_2O_3} $$
#
# - Solar abundance (molar abundance) of Al: 8.51 x 10$^4$
# - Solar abundance (molar abundance) of O: 2.36 x 10$^7$
# - Solar abundance (molar abundance) of H: 2.6 x 10$^{10}$
# - Pressure in the nebula: 10$^{-3}$ atm
# - Gas constant (R): 8.314 J/mol K
# - $\Delta$G$^\circ$ (standard free energy of reaction) for condensation of Al$_2$O$_3$: -1.23 x 10$^6$ J/mol
#
# **Q2**: At what temperature will this reaction finish condensing all of the Aluminum in the nebula?

# %%
from matplotlib import pyplot as plt
import numpy as np

nAl = 8.51e4
nO = 2.36e7
nH = 2.6e10
pT = 1e-4
R = 8.314
dG = -1.23e6
pAl = ((2*nAl)/nH*pT)
pO = ((2*nO)/nH*pT)

Q = 1/(pAl**2*pO**3)
print(-dG/(R*np.log(Q)))

x = 0.495 * pAl
Q2 = 1/((pAl-2*x)**2*(pO-3*x)**3)
print(-dG/(R*np.log(Q2)))
print((pAl-2*x)/pAl)


T=np.linspace(1000,2000,100)
x = -1e4/T #(minus makes x axis cold to hot)
y = dG/(R*T) #(minus sign reverses the reaction)

plt.plot(x,y) 

# x = np.linspace(0,.99,1000)
# y = 1.23e6/(8.314*np.log(1/((pAl-x*pAl)**2*(pO-(3/2)*x*pAl)**3)))
# plt.plot(x,y)
# Out:
# 1664.914751456872
# 1508.304406358246
# 0.010000000000000005

# %% [markdown]
# <center>
#     <div style='height:85vh;'>
# 	    <img src="images/nebula_partial_p_.png" style='height:85vh'>
#     </div>
# </center>

# %% [markdown]
# <center>
#     <div style='height:85vh;'>
# 	    <img src="images/condense.png" style='height:85vh'>
#     </div>
# </center>

# %% [markdown]
# <center>
#     <div style='height:85vh;'>
# 	    <img src="images/condense_solution_1.png" style='height:85vh'>
#     </div>
# </center>

# %% [markdown]
# <center>
#     <div style='height:85vh;'>
# 	    <img src="images/condense_solution_2.png" style='height:85vh'>
#     </div>
# </center>

# %% [markdown]
# <center>
#     <div style='height:800px;'>
# 	    <img src="images/condensation.png" style='height:800px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# ### <span style='color:dodgerblue'>Not quite as simple as our example..</span>
#
# <center>
#     <div style='height:700px;'>
# 	    <img src="images/grossman_system.png" style='height:800px'>
#     </div>
#     <br>
#     <span style='font-size:.7em'>table from <i>Condensation in the primitive solar nebula</i> by Lawrence Grossman in GCA (1972)</span>
# </center>
# <p></p>

# %% [markdown]
# ### <span style='color:dodgerblue'>Not quite as simple as our example..</span>
#
# <center>
#     <div style='height:700px;'>
# 	    <img src="images/grossman_system2.png" style='height:800px'>
#     </div><br>
#     <span style='font-size:.7em'>figure from <i>Condensation in the primitive solar nebula</i> by Lawrence Grossman in GCA (1972)</span>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <div style='height:800px;'>
# 	    <img src="images/condensation.png" style='height:800px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <center>
#     <span style='font-weight:600;color:DodgerBlue'>Earth $\approx$ MgO + CaO + SiO$_2$ + Al$_2$O$_3$ + FeO</span>
# </center>

# %% [markdown]
# ### Forming the planets
# <br>
#
# <center>
# <video controls src="videos/planet_formation.mp4" />
# </center>

# %% [markdown]
# <span style='font-weight:600;color:DodgerBlue'>Define Goldschmidt classification.</span><p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L3_S27_F0.svg" style='height:700px'/></center>

# %% [markdown]
# <span style='font-weight:600;color:DodgerBlue'>Define Goldschmidt classification.</span><p></p>

# %% [markdown]
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/RLE.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# <span style='font-weight:600;color:DodgerBlue'>Define Primitive Mantle. What do we know about the modern mantle?</span><br>
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L4_S28_F0.svg" style='height:700px'/></center>

# %% [markdown]
# Olivine Solid Solution Phase Diagram.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L4_S29_F0.svg" style='height:700px'/></center>

# %% [markdown]
# Melting trends.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L4_S30_F0.svg" style='height:700px'/></center>

# %% [markdown]
# <center><img src="chalkboard_images/L5_S31_F0.svg" style='height:700px'/></center>
#
#
#
# **Pyrolite Model**: Ringwood, A.E., 1962. **A model for the upper mantle**. *Journal of Geophysical Research*.

# %% [markdown]
# Chondrites
#
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/cai.jpg" style='height:550px'>
#     </div>
# </center>
#
# <p></p>

# %% [markdown]
# Chondrules: molten 'droplets' of nebular dust
#
# AOAs: Ameboidal Olivine Aggregates ~100% olivine
#
# CAIs: Calcium Aluminum Inclusions are the first condensates

# %% [markdown]
# Mineralogy of Chondrite phases
#
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/chondrite_phases.jpg" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# Chondrites have variable composition
#
# <center>
#     <div style='height:650px;'>
# 	    <img src="images/mg_si_chond.png" style='height:650px'>
#     </div>
# </center>
# <p></p>

# %% [markdown]
# ### Practice problem
# The observed chondritic mass abundances for Calcium and Aluminum are:
#
# | Element        | wt % in Chondrite           | Atomic Mass  |
# | ------------- |:-------------:| -----:|
# | Ca | 0.92     |    40.1 |
# | Al | 0.85      |    27 |
#
# The average wt % of CaO and Al$_2$O$_3$ in Basalt and Harzburgite:
#
# | **Oxide**        | wt % in Basalt           | wt % in Harzburgite   |
# | ------------- |:-------------:| -----:|
# | CaO | 11.3     |   6.1 |
# | Al$_2$O$_3$ | 15.1      |    5.1 |
#
# What ratio do you need to mix basalt and harzburgite back together to get the composition of the mantle before melt was removed? Assumptions:
#
# - Pyrolite is a combination of melt (basalt) and melted mantle (harzburgites)
# - Earth has the same Refractory Lithophile Elemental (RLE) abundances as Chondrites

# %% [markdown]
# Solution.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L5_S35_F0.svg" style='height:700px'/></center>

# %% [markdown]
# Solution.
# <p></p>

# %% [markdown]
# <center><img src="chalkboard_images/L5_S36_F0.svg" style='height:700px'/></center>
